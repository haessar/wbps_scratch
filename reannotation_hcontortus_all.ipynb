# %%
import os.path
import json
import statistics
from collections import Counter

from orthologue_analysis.orthogroups import init_orthogroup_df
from orthologue_analysis.species import HaemonchusFromTool, SpeciesList
from orthologue_analysis.utils import SequenceIDMapping, orthofinder_paths
from reannotation.analysis import (
    interpro_accessions_frequently_missed_by_each_tool,
    interpro_accessions_frequently_missed_by_all_tools,
    interpro_accessions_in_novel_transcripts,
    interpro_accessions_in_missed_transcripts,
    missed_transcripts_with_significantly_more_frequent_accessions
)
from reannotation.constants import ASPARTIC_PEPTIDASE_SUPERFAMILY
from reannotation.pipelines import (
    interpro_accession_pipeline,
    interpro_accession_pipeline_all_tools,
    suspicious_orthologue_pipeline,
    pickle_cache_suspicious_orthologue_pipeline,
    novel_orthologue_pipeline
)
from reannotation.statistics import fisher_exact_for_two_lists_of_accessions
from utils.esm import extract_esm_means
from utils.generic import flatten_nested_dict
from utils.gffutils import init_db


results_label = "Results_Aug08"
wbps_ann_path = "data/from_WBPS/haemonchus_contortus.PRJEB506.WBPS19.annotations.gff3"
braker_path = "data/from_MARS/Haemonchus_contortus_braker3_full.gff3"
helixer_path = "data/from_MARS/Haemonchus_contortus_helixer_full.gff3"
anno_path = "data/from_EBI/haemonchus_contortus_gca000469685v2.gff3"
db = init_db(wbps_ann_path, "db/Hcon_wbps.db")
of = orthofinder_paths(results_label, subdir="Orthogroups")

wbps_col = "Hcon_LT"
braker_col = "Hcon_braker3_LT"
helixer_col = "Hcon_helixer_LT"
anno_col = "Hcon_anno_LT"

og_df = init_orthogroup_df(of["orthogroups"])
no_og_df = init_orthogroup_df(of["orthogroups_unassigned_genes"])
seq_id_map = SequenceIDMapping(of["wd"])
mars_data_dir = os.path.join("data", "from_MARS", "")
ebi_data_dir = os.path.join("data", "from_EBI", "")

species_list = SpeciesList([
    HaemonchusFromTool("contortus", data_dir=mars_data_dir, data_label="Hcon_LT", prot_filename_suffix=".fa"),
    HaemonchusFromTool("contortus_braker3_reann", data_dir=mars_data_dir, data_label="Hcon_braker3_LT", prot_filename_suffix=".fa"),
    HaemonchusFromTool("contortus_helixer_reann", data_dir=mars_data_dir, data_label="Hcon_helixer_LT", prot_filename_suffix=".fa"),
    HaemonchusFromTool("contortus_anno_reann", data_dir=ebi_data_dir, data_label="Hcon_anno_LT", prot_filename_suffix=".fa")],
    wd_path=of["wd"],
    load_blast=True
)

wbps_species = species_list.get_species_with_data_label(wbps_col)
braker_species = species_list.get_species_with_data_label(braker_col)
helixer_species = species_list.get_species_with_data_label(helixer_col)
anno_species = species_list.get_species_with_data_label(anno_col)

with open("data/acc_product_hcontortus.json", "r") as f:
    acc_product = json.loads(f.read())

min_freq = 10

interproscan_dir = "data/from_MARS/interproscan/hcon"
# Out:
# loading /home/will/wbp_scratch/data/from_MARS/OrthoFinder/WorkingDirectory/Results_Aug08/Blast0_1.txt...
# loading /home/will/wbp_scratch/data/from_MARS/OrthoFinder/WorkingDirectory/Results_Aug08/Blast0_2.txt...
# loading /home/will/wbp_scratch/data/from_MARS/OrthoFinder/WorkingDirectory/Results_Aug08/Blast0_3.txt...
# loading /home/will/wbp_scratch/data/from_MARS/OrthoFinder/WorkingDirectory/Results_Aug08/Blast0_2.txt...
# loading /home/will/wbp_scratch/data/from_MARS/OrthoFinder/WorkingDirectory/Results_Aug08/Blast0_3.txt...
# loading /home/will/wbp_scratch/data/from_MARS/OrthoFinder/WorkingDirectory/Results_Aug08/Blast0_1.txt...

# %% [markdown]
# # General Statistics

# %%
print("Shared orthologues with WBPS:")
print("WBPS: {}".format(len(og_df[~og_df[wbps_col].isna()])))
print("BRAKER3: {}".format(len(og_df[~og_df[wbps_col].isna() & ~og_df[braker_col].isna()])))
print("Helixer: {}".format(len(og_df[~og_df[wbps_col].isna() & ~og_df[helixer_col].isna()])))
print("Anno: {}".format(len(og_df[~og_df[wbps_col].isna() & ~og_df[anno_col].isna()])))
# Out:
# Shared orthologues with WBPS:
# WBPS: 14248
# BRAKER3: 11998
# Helixer: 13154
# Anno: 13088

# %% [markdown]
# # Assessing merged/split genes

# %%
braker_merged, braker_split = pickle_cache_suspicious_orthologue_pipeline("braker", "hcon", og_df, wbps_col, braker_col, species_list, seq_id_map)
anno_merged, anno_split = pickle_cache_suspicious_orthologue_pipeline("anno", "hcon", og_df, wbps_col, anno_col, species_list, seq_id_map)
helixer_merged, helixer_split = pickle_cache_suspicious_orthologue_pipeline("helixer", "hcon", og_df, wbps_col, helixer_col, species_list, seq_id_map)
# Out:
# 100%|██████████| 15714/15714 [06:46<00:00, 38.69it/s]
# 100%|██████████| 15714/15714 [08:46<00:00, 29.85it/s]
# 100%|██████████| 15714/15714 [11:45<00:00, 22.27it/s]

# %%
num_genes = len(list(braker_species.db.all_features(featuretype="gene")))
print(f"BRAKER3: merged={len(braker_merged)}, split={len(braker_split)}, total={round(100*(len(braker_split) + len(braker_merged)*2)/num_genes, 2)}")
num_genes = len(list(helixer_species.db.all_features(featuretype="gene")))
print(f"Helixer: merged={len(helixer_merged)}, split={len(helixer_split)}, total={round(100*(len(helixer_split) + len(helixer_merged)*2)/num_genes, 2)}")
num_genes = len(list(anno_species.db.all_features(featuretype="gene")))
print(f"Anno: merged={len(anno_merged)}, split={len(anno_split)}, total={round(100*(len(anno_split) + len(anno_merged)*2)/num_genes, 2)}")
# Out:
# BRAKER3: merged=42, split=38, total=0.84
# Helixer: merged=176, split=71, total=2.21
# Anno: merged=297, split=47, total=3.06

# %% [markdown]
# # InterPro accession investigation

# %% [markdown]
# ### BRAKER3

# %%
acc_tally_shared_braker3, acc_tally_missed_braker3, acc_tally_novel_braker3, missed_transcripts = interpro_accession_pipeline(db, og_df, wbps_col, braker_col, interproscan_dir)
_, acc_tally_missed_braker3_unassigned, acc_tally_novel_braker3_unassigned, _ = interpro_accession_pipeline(db, no_og_df, wbps_col, braker_col, os.path.join(interproscan_dir, "unassigned_genes"))
acc_tally_missed_braker3 += acc_tally_missed_braker3_unassigned
acc_tally_novel_braker3 += acc_tally_novel_braker3_unassigned

# Find InterPro accessions occurring with significantly different frequency than in control (acc_tally_shared_braker3)
braker3_novel_results = fisher_exact_for_two_lists_of_accessions(acc_tally_novel_braker3, acc_tally_shared_braker3 + acc_tally_missed_braker3)
braker3_missed_results = fisher_exact_for_two_lists_of_accessions(acc_tally_missed_braker3, acc_tally_shared_braker3 + acc_tally_novel_braker3)

# %%
list(interpro_accessions_in_novel_transcripts(flatten_nested_dict(acc_product), acc_tally_novel_braker3, braker3_novel_results, min_freq=10))
# Out:
# InterPro accessions occurring with significantly higher frequency in novel transcripts than in shared transcripts:
# 	IPR002486: Nematode cuticle collagen, N-terminal (16 occurrences, 2 expected)
# 	IPR008160: Collagen triple helix repeat (15 occurrences, 2 expected)
# 	IPR035940: CAP superfamily (14 occurrences, 4 expected)
#
# InterPro accessions that are completely missing from shared transcripts, with high frequency in novel transcripts:
# ['IPR002486', 'IPR008160', 'IPR035940']

# %%
interpro_accessions_in_missed_transcripts(flatten_nested_dict(acc_product), acc_tally_missed_braker3, acc_tally_novel_braker3, braker3_missed_results, braker3_novel_results, min_freq=75)
# Out:
# InterPro accessions that are completely missing from shared transcripts, with high frequency in missed transcripts:
#
# InterPro accessions occurring with significantly higher frequency in missed transcripts than in shared transcripts:
# 	IPR005312: Protein of unknown function DUF1759 (157 occurrences, 5 expected)
# 	IPR001584: Integrase, catalytic core (164 occurrences, 6 expected)
# 	IPR041588: Integrase zinc-binding domain (152 occurrences, 6 expected)
# 	IPR001995: Peptidase A2A, retrovirus, catalytic (94 occurrences, 4 expected)
# 	IPR008737: Peptidase aspartic, putative (94 occurrences, 4 expected)
# 	IPR008042: Retrotransposon, Pao (124 occurrences, 6 expected)
# 	IPR040676: Domain of unknown function DUF5641 (87 occurrences, 4 expected)
# 	IPR036397: Ribonuclease H superfamily (403 occurrences, 24 expected)
# 	IPR001878: Zinc finger, CCHC-type (101 occurrences, 7 expected)
# 	IPR018244: Allergen V5/Tpx-1-related, conserved site (96 occurrences, 7 expected)
# 	IPR012337: Ribonuclease H-like superfamily (178 occurrences, 15 expected)
# 	IPR021109: Aspartic peptidase domain superfamily (213 occurrences, 19 expected)
# 	IPR001969: Aspartic peptidase, active site (117 occurrences, 13 expected)
# 	IPR043128: Reverse transcriptase/Diguanylate cyclase domain (260 occurrences, 30 expected)
# 	IPR043502: DNA/RNA polymerase superfamily (444 occurrences, 51 expected)
# 	IPR002413: Venom allergen 5-like (96 occurrences, 12 expected)
# 	IPR000477: Reverse transcriptase domain (441 occurrences, 57 expected)
# 	IPR001283: Cysteine-rich secretory protein-related (121 occurrences, 19 expected)
# 		IPR001283 also significantly more frequent in novel transcripts (8 occurrences, 3 expected)
# 	IPR035940: CAP superfamily (161 occurrences, 25 expected)
# 		IPR035940 also significantly more frequent in novel transcripts (14 occurrences, 4 expected)
# 	IPR014044: CAP domain (130 occurrences, 21 expected)
# 		IPR014044 also significantly more frequent in novel transcripts (8 occurrences, 3 expected)
# 	IPR036691: Endonuclease/exonuclease/phosphatase superfamily (135 occurrences, 31 expected)
# 	IPR009057: Homeobox-like domain superfamily (76 occurrences, 23 expected)
#
# InterPro accessions occurring as expected in missed transcripts with high frequency:
# 	IPR027417: P-loop containing nucleoside triphosphate hydrolase (100 occurrences)
#
# InterPro accessions occurring less frequently in missed transcripts than expected:
# 	IPR000719: Protein kinase domain (27 occurrences, 61 expected)
# 	IPR011009: Protein kinase-like domain superfamily (30 occurrences, 71 expected)
# 	IPR001304: C-type lectin-like (6 occurrences, 17 expected)
# 	IPR016186: C-type lectin-like/link domain superfamily (7 occurrences, 18 expected)
# 	IPR016187: C-type lectin fold (8 occurrences, 19 expected)
# 	IPR017452: GPCR, rhodopsin-like, 7TM (31 occurrences, 46 expected)
# 	IPR029063: S-adenosyl-L-methionine-dependent methyltransferase superfamily (10 occurrences, 20 expected)
# 	IPR013083: Zinc finger, RING/FYVE/PHD-type (16 occurrences, 33 expected)
# 	IPR008271: Serine/threonine-protein kinase, active site (14 occurrences, 32 expected)
# 	IPR017441: Protein kinase, ATP binding site (16 occurrences, 39 expected)
# 	IPR005225: Small GTP-binding protein domain (5 occurrences, 15 expected)
# 	IPR029071: Ubiquitin-like domain superfamily (4 occurrences, 16 expected)
# 	IPR032675: Leucine-rich repeat domain superfamily (5 occurrences, 14 expected)
# 	IPR002347: Short-chain dehydrogenase/reductase SDR (1 occurrences, 9 expected)
# 	IPR036291: NAD(P)-binding domain superfamily (5 occurrences, 22 expected)
# 	IPR002486: Nematode cuticle collagen, N-terminal (12 occurrences, 30 expected)
# 	IPR008160: Collagen triple helix repeat (14 occurrences, 29 expected)
# 	IPR035892: C2 domain superfamily (3 occurrences, 12 expected)
# 	IPR013766: Thioredoxin domain (1 occurrences, 7 expected)
# 	IPR036249: Thioredoxin-like superfamily (5 occurrences, 20 expected)
# 	IPR011993: PH-like domain superfamily (7 occurrences, 24 expected)
# 	IPR001478: PDZ domain (3 occurrences, 10 expected)
# 	IPR036034: PDZ superfamily (3 occurrences, 12 expected)
# 	IPR011701: Major facilitator superfamily (5 occurrences, 14 expected)
# 	IPR036259: MFS transporter superfamily (8 occurrences, 30 expected)
# 	IPR011990: Tetratricopeptide-like helical domain superfamily (7 occurrences, 22 expected)
# 	IPR019734: Tetratricopeptide repeat (4 occurrences, 12 expected)
# 	IPR001650: Helicase, C-terminal (5 occurrences, 14 expected)
# 	IPR011545: DEAD/DEAH box helicase domain (3 occurrences, 10 expected)
# 	IPR014001: Helicase superfamily 1/2, ATP-binding domain (6 occurrences, 14 expected)
# 	IPR001452: SH3 domain (3 occurrences, 10 expected)
# 	IPR012677: Nucleotide-binding alpha-beta plait domain superfamily (7 occurrences, 25 expected)
# 	IPR035979: RNA-binding domain superfamily (7 occurrences, 25 expected)
# 	IPR000536: Nuclear hormone receptor, ligand-binding domain (2 occurrences, 11 expected)
# 	IPR001628: Zinc finger, nuclear hormone receptor-type (2 occurrences, 11 expected)
# 	IPR013087: Zinc finger C2H2-type (15 occurrences, 32 expected)
# 	IPR013088: Zinc finger, NHR/GATA-type (2 occurrences, 13 expected)
# 	IPR035500: Nuclear hormone receptor-like domain superfamily (2 occurrences, 12 expected)
# 	IPR001680: WD40 repeat (5 occurrences, 27 expected)
# 	IPR015943: WD40/YVTN repeat-like-containing domain superfamily (7 occurrences, 33 expected)
# 	IPR019775: WD40 repeat, conserved site (3 occurrences, 11 expected)
# 	IPR036322: WD40-repeat-containing domain superfamily (5 occurrences, 31 expected)
# 	IPR002048: EF-hand domain (4 occurrences, 16 expected)
# 	IPR011992: EF-hand domain pair (3 occurrences, 18 expected)
# 	IPR018247: EF-Hand 1, calcium-binding site (2 occurrences, 15 expected)
# 	IPR036236: Zinc finger C2H2 superfamily (6 occurrences, 20 expected)
# 	IPR011989: Armadillo-like helical (4 occurrences, 24 expected)
# 	IPR016024: Armadillo-type fold (8 occurrences, 36 expected)
# 	IPR017853: Glycoside hydrolase superfamily (3 occurrences, 11 expected)
# 	IPR000504: RNA recognition motif domain (5 occurrences, 23 expected)
# 	IPR020901: Proteinase inhibitor I2, Kunitz, conserved site (1 occurrences, 6 expected)
# 	IPR003593: AAA+ ATPase domain (9 occurrences, 19 expected)
# 	IPR000859: CUB domain (6 occurrences, 14 expected)
# 	IPR043129: ATPase, nucleotide binding domain (1 occurrences, 8 expected)
# 	IPR006201: Neurotransmitter-gated ion-channel (8 occurrences, 19 expected)
# 	IPR036719: Neurotransmitter-gated ion-channel transmembrane domain superfamily (7 occurrences, 18 expected)
# 	IPR038050: Neuronal acetylcholine receptor (7 occurrences, 18 expected)
# 	IPR006028: Gamma-aminobutyric acid A receptor/Glycine receptor alpha (1 occurrences, 8 expected)
# 	IPR006029: Neurotransmitter-gated ion-channel transmembrane domain (4 occurrences, 15 expected)
# 	IPR006202: Neurotransmitter-gated ion-channel ligand-binding domain (7 occurrences, 18 expected)
# 	IPR018000: Neurotransmitter-gated ion-channel, conserved site (4 occurrences, 16 expected)
# 	IPR036734: Neurotransmitter-gated ion-channel ligand-binding domain superfamily (8 occurrences, 19 expected)
# 	IPR000971: Globin (1 occurrences, 7 expected)
# 	IPR009050: Globin-like superfamily (1 occurrences, 9 expected)
# 	IPR012292: Globin/Protoglobin (1 occurrences, 10 expected)
# 	IPR044399: Myoglobin-like, M family globin domain (1 occurrences, 7 expected)
# 	IPR002110: Ankyrin repeat (3 occurrences, 14 expected)
# 	IPR036770: Ankyrin repeat-containing domain superfamily (3 occurrences, 15 expected)
# 	IPR032710: NTF2-like domain superfamily (2 occurrences, 8 expected)
# 	IPR001534: Transthyretin-like (3 occurrences, 13 expected)
# 	IPR038479: Transthyretin-like superfamily (3 occurrences, 14 expected)
# 	IPR001723: Nuclear hormone receptor (1 occurrences, 6 expected)
# 	IPR011527: ABC transporter type 1, transmembrane domain (1 occurrences, 6 expected)
# 	IPR036640: ABC transporter type 1, transmembrane domain superfamily (1 occurrences, 6 expected)
# 	IPR001054: Adenylyl cyclase class-3/4/guanylyl cyclase (1 occurrences, 7 expected)
# %%
list(interpro_accessions_in_novel_transcripts(flatten_nested_dict(acc_product), acc_tally_novel_helixer, helixer_novel_results, min_freq))
# Out:
# InterPro accessions occurring with significantly higher frequency in novel transcripts than in shared transcripts:
# 	IPR019421: 7TM GPCR, serpentine receptor class d (Srd) (12 occurrences, 1 expected)
# 	IPR019424: Serpentine type 7TM GPCR chemoreceptor Srsx (11 occurrences, 2 expected)
# 	IPR019426: 7TM GPCR, serpentine receptor class v (Srv) (14 occurrences, 2 expected)
# 	IPR002486: Nematode cuticle collagen, N-terminal (19 occurrences, 4 expected)
# 	IPR008160: Collagen triple helix repeat (17 occurrences, 4 expected)
# 	IPR035940: CAP superfamily (16 occurrences, 7 expected)
# 	IPR003582: ShKT domain (10 occurrences, 5 expected)
# 	IPR000276: G protein-coupled receptor, rhodopsin-like (10 occurrences, 5 expected)
# 	IPR017452: GPCR, rhodopsin-like, 7TM (12 occurrences, 6 expected)
#
# InterPro accessions that are completely missing from shared transcripts, with high frequency in novel transcripts:
# ['IPR019421',
#  'IPR019424',
#  'IPR019426',
#  'IPR002486',
#  'IPR008160',
#  'IPR035940',
#  'IPR003582',
#  'IPR000276',
#  'IPR017452']

# %%
interpro_accessions_in_missed_transcripts(flatten_nested_dict(acc_product), acc_tally_missed_helixer, acc_tally_novel_helixer, helixer_missed_results, helixer_novel_results, min_freq=30)
# Out:
# InterPro accessions that are completely missing from shared transcripts, with high frequency in missed transcripts:
#
# InterPro accessions occurring with significantly higher frequency in missed transcripts than in shared transcripts:
# 	IPR027124: SWR1-complex protein 5/Craniofacial development protein 1/2 (38 occurrences, 2 expected)
# 	IPR036691: Endonuclease/exonuclease/phosphatase superfamily (151 occurrences, 10 expected)
# 	IPR005135: Endonuclease/exonuclease/phosphatase (55 occurrences, 6 expected)
# 	IPR000477: Reverse transcriptase domain (245 occurrences, 33 expected)
# 	IPR001461: Aspartic peptidase A1 family (32 occurrences, 5 expected)
# 	IPR033121: Peptidase family A1 domain (32 occurrences, 5 expected)
# 	IPR043502: DNA/RNA polymerase superfamily (218 occurrences, 33 expected)
# 	IPR043128: Reverse transcriptase/Diguanylate cyclase domain (120 occurrences, 20 expected)
# 	IPR008042: Retrotransposon, Pao (44 occurrences, 8 expected)
# 	IPR001969: Aspartic peptidase, active site (49 occurrences, 9 expected)
# 	IPR036397: Ribonuclease H superfamily (137 occurrences, 27 expected)
# 	IPR018244: Allergen V5/Tpx-1-related, conserved site (33 occurrences, 7 expected)
# 	IPR035940: CAP superfamily (72 occurrences, 15 expected)
# 		IPR035940 also significantly more frequent in novel transcripts (16 occurrences, 7 expected)
# 	IPR005312: Protein of unknown function DUF1759 (45 occurrences, 10 expected)
# 	IPR002413: Venom allergen 5-like (35 occurrences, 8 expected)
# 	IPR001584: Integrase, catalytic core (41 occurrences, 11 expected)
# 	IPR021109: Aspartic peptidase domain superfamily (64 occurrences, 17 expected)
# 	IPR001283: Cysteine-rich secretory protein-related (42 occurrences, 12 expected)
# 	IPR041588: Integrase zinc-binding domain (35 occurrences, 11 expected)
# 	IPR014044: CAP domain (43 occurrences, 13 expected)
# 	IPR012337: Ribonuclease H-like superfamily (43 occurrences, 15 expected)
#
# InterPro accessions occurring as expected in missed transcripts with high frequency:
# 	IPR027417: P-loop containing nucleoside triphosphate hydrolase (33 occurrences)
#
# InterPro accessions occurring less frequently in missed transcripts than expected:
# 	IPR016024: Armadillo-type fold (1 occurrences, 13 expected)
# 	IPR017452: GPCR, rhodopsin-like, 7TM (9 occurrences, 18 expected)
# 	IPR011992: EF-hand domain pair (1 occurrences, 7 expected)
# 	IPR006201: Neurotransmitter-gated ion-channel (1 occurrences, 7 expected)
# 	IPR006202: Neurotransmitter-gated ion-channel ligand-binding domain (1 occurrences, 7 expected)
# 	IPR018000: Neurotransmitter-gated ion-channel, conserved site (1 occurrences, 6 expected)
# 	IPR036719: Neurotransmitter-gated ion-channel transmembrane domain superfamily (1 occurrences, 7 expected)
# 	IPR036734: Neurotransmitter-gated ion-channel ligand-binding domain superfamily (1 occurrences, 7 expected)
# 	IPR038050: Neuronal acetylcholine receptor (1 occurrences, 7 expected)
# 	IPR000719: Protein kinase domain (6 occurrences, 23 expected)
# 	IPR011009: Protein kinase-like domain superfamily (7 occurrences, 27 expected)
# 	IPR008271: Serine/threonine-protein kinase, active site (1 occurrences, 12 expected)
# 	IPR017441: Protein kinase, ATP binding site (2 occurrences, 15 expected)
# 	IPR013083: Zinc finger, RING/FYVE/PHD-type (5 occurrences, 13 expected)
# 	IPR001680: WD40 repeat (3 occurrences, 10 expected)
# 	IPR015943: WD40/YVTN repeat-like-containing domain superfamily (3 occurrences, 12 expected)
# 	IPR036322: WD40-repeat-containing domain superfamily (3 occurrences, 11 expected)
# 	IPR000276: G protein-coupled receptor, rhodopsin-like (3 occurrences, 13 expected)
# 	IPR000504: RNA recognition motif domain (2 occurrences, 8 expected)
# 	IPR012677: Nucleotide-binding alpha-beta plait domain superfamily (2 occurrences, 9 expected)
# 	IPR035979: RNA-binding domain superfamily (2 occurrences, 9 expected)

# %% [markdown]
# ### Anno

# %%
acc_tally_shared_anno, acc_tally_missed_anno, acc_tally_novel_anno, missed_transcripts = interpro_accession_pipeline(db, og_df, wbps_col, anno_col, interproscan_dir)
_, acc_tally_missed_anno_unassigned, acc_tally_novel_anno_unassigned, _ = interpro_accession_pipeline(db, no_og_df, wbps_col, anno_col, os.path.join(interproscan_dir, "unassigned_genes"))
acc_tally_missed_anno += acc_tally_missed_anno_unassigned
acc_tally_novel_anno += acc_tally_novel_anno_unassigned

# Find InterPro accessions occurring with significantly different frequency than in control (acc_tally_shared_anno)
anno_novel_results = fisher_exact_for_two_lists_of_accessions(acc_tally_novel_anno, acc_tally_shared_anno + acc_tally_missed_anno)
anno_missed_results = fisher_exact_for_two_lists_of_accessions(acc_tally_missed_anno, acc_tally_shared_anno + acc_tally_novel_anno)

# %%
list(interpro_accessions_in_novel_transcripts(flatten_nested_dict(acc_product), acc_tally_novel_anno, anno_novel_results, min_freq=10))
# Out:
# InterPro accessions occurring with significantly higher frequency in novel transcripts than in shared transcripts:
# 	IPR019426: 7TM GPCR, serpentine receptor class v (Srv) (13 occurrences, 3 expected)
# 	IPR002486: Nematode cuticle collagen, N-terminal (18 occurrences, 4 expected)
# 	IPR008160: Collagen triple helix repeat (16 occurrences, 4 expected)
# 	IPR000742: EGF-like domain (11 occurrences, 4 expected)
# 	IPR003582: ShKT domain (13 occurrences, 5 expected)
# 	IPR017452: GPCR, rhodopsin-like, 7TM (17 occurrences, 7 expected)
#
# InterPro accessions that are completely missing from shared transcripts, with high frequency in novel transcripts:
# ['IPR019426', 'IPR002486', 'IPR008160', 'IPR000742', 'IPR003582', 'IPR017452']

# %%
interpro_accessions_in_missed_transcripts(flatten_nested_dict(acc_product), acc_tally_missed_anno, acc_tally_novel_anno, anno_missed_results, anno_novel_results, min_freq=50)
# Out:
# InterPro accessions that are completely missing from shared transcripts, with high frequency in missed transcripts:
#
# InterPro accessions occurring with significantly higher frequency in missed transcripts than in shared transcripts:
# 	IPR040676: Domain of unknown function DUF5641 (52 occurrences, 5 expected)
# 	IPR008737: Peptidase aspartic, putative (54 occurrences, 5 expected)
# 	IPR001995: Peptidase A2A, retrovirus, catalytic (53 occurrences, 6 expected)
# 	IPR036691: Endonuclease/exonuclease/phosphatase superfamily (128 occurrences, 14 expected)
# 	IPR041588: Integrase zinc-binding domain (78 occurrences, 9 expected)
# 	IPR005312: Protein of unknown function DUF1759 (79 occurrences, 10 expected)
# 	IPR021109: Aspartic peptidase domain superfamily (130 occurrences, 16 expected)
# 	IPR001584: Integrase, catalytic core (79 occurrences, 10 expected)
# 	IPR008042: Retrotransposon, Pao (61 occurrences, 8 expected)
# 	IPR005135: Endonuclease/exonuclease/phosphatase (56 occurrences, 7 expected)
# 	IPR001969: Aspartic peptidase, active site (73 occurrences, 10 expected)
# 	IPR000477: Reverse transcriptase domain (268 occurrences, 40 expected)
# 	IPR043128: Reverse transcriptase/Diguanylate cyclase domain (150 occurrences, 23 expected)
# 	IPR043502: DNA/RNA polymerase superfamily (253 occurrences, 39 expected)
# 	IPR012337: Ribonuclease H-like superfamily (82 occurrences, 15 expected)
# 	IPR036397: Ribonuclease H superfamily (161 occurrences, 32 expected)
# 	IPR035940: CAP superfamily (86 occurrences, 17 expected)
# 	IPR001283: Cysteine-rich secretory protein-related (52 occurrences, 14 expected)
# 	IPR014044: CAP domain (56 occurrences, 16 expected)
#
# InterPro accessions occurring as expected in missed transcripts with high frequency:
#
# InterPro accessions occurring less frequently in missed transcripts than expected:
# 	IPR000276: G protein-coupled receptor, rhodopsin-like (3 occurrences, 16 expected)
# 	IPR017452: GPCR, rhodopsin-like, 7TM (4 occurrences, 23 expected)
# 	IPR011989: Armadillo-like helical (2 occurrences, 11 expected)
# 	IPR016024: Armadillo-type fold (4 occurrences, 16 expected)
# 	IPR035892: C2 domain superfamily (1 occurrences, 6 expected)
# 	IPR029021: Protein-tyrosine phosphatase-like (1 occurrences, 6 expected)
# 	IPR000719: Protein kinase domain (11 occurrences, 29 expected)
# 	IPR008271: Serine/threonine-protein kinase, active site (5 occurrences, 15 expected)
# 	IPR011009: Protein kinase-like domain superfamily (12 occurrences, 33 expected)
# 	IPR036249: Thioredoxin-like superfamily (3 occurrences, 9 expected)
# 	IPR013083: Zinc finger, RING/FYVE/PHD-type (3 occurrences, 16 expected)
# 	IPR001841: Zinc finger, RING-type (2 occurrences, 9 expected)
# 	IPR013087: Zinc finger C2H2-type (3 occurrences, 16 expected)
# 	IPR036236: Zinc finger C2H2 superfamily (2 occurrences, 10 expected)
# 	IPR017441: Protein kinase, ATP binding site (4 occurrences, 18 expected)
# 	IPR011993: PH-like domain superfamily (4 occurrences, 11 expected)
# 	IPR036291: NAD(P)-binding domain superfamily (1 occurrences, 10 expected)
# 	IPR011990: Tetratricopeptide-like helical domain superfamily (3 occurrences, 10 expected)
# 	IPR002048: EF-hand domain (1 occurrences, 7 expected)
# 	IPR011992: EF-hand domain pair (2 occurrences, 8 expected)
# 	IPR018247: EF-Hand 1, calcium-binding site (1 occurrences, 7 expected)
# 	IPR000742: EGF-like domain (3 occurrences, 14 expected)
# 	IPR017050: Metallopeptidase, nematode (1 occurrences, 7 expected)
# 	IPR038765: Papain-like cysteine peptidase superfamily (1 occurrences, 11 expected)
# 	IPR001680: WD40 repeat (1 occurrences, 12 expected)
# 	IPR015943: WD40/YVTN repeat-like-containing domain superfamily (1 occurrences, 15 expected)
# 	IPR036322: WD40-repeat-containing domain superfamily (1 occurrences, 14 expected)
# 	IPR019426: 7TM GPCR, serpentine receptor class v (Srv) (1 occurrences, 9 expected)
# 	IPR036259: MFS transporter superfamily (4 occurrences, 14 expected)
# 	IPR020846: Major facilitator superfamily domain (2 occurrences, 8 expected)
# 	IPR001650: Helicase, C-terminal (1 occurrences, 7 expected)
# 	IPR013320: Concanavalin A-like lectin/glucanase domain superfamily (1 occurrences, 6 expected)
# 	IPR000859: CUB domain (1 occurrences, 7 expected)
# 	IPR035914: Spermadhesin, CUB domain superfamily (1 occurrences, 8 expected)

# %% [markdown]
# ### General

# %% [markdown]
# Find accessions that are significantly commonly missed by **all** tools

# %%
acc_tally_no_tool, acc_tally_one_plus_tool_shared, acc_tally_one_plus_tool_novel = interpro_accession_pipeline_all_tools(
    wbps_species,
    og_df,
    wbps_col,
    [braker_col, helixer_col, anno_col],
    interproscan_dir
)

acc_tally_no_tool_unassigned, _, acc_tally_one_plus_tool_novel_unassigned = interpro_accession_pipeline_all_tools(
    wbps_species,
    no_og_df,
    wbps_col,
    [braker_col, helixer_col, anno_col],
    os.path.join(interproscan_dir, "unassigned_genes")
)
acc_tally_no_tool += acc_tally_no_tool_unassigned
acc_tally_one_plus_tool_novel += acc_tally_one_plus_tool_novel_unassigned

no_tools_results = fisher_exact_for_two_lists_of_accessions(acc_tally_no_tool, acc_tally_one_plus_tool_shared + acc_tally_one_plus_tool_novel)
only_tools_results = fisher_exact_for_two_lists_of_accessions(acc_tally_one_plus_tool_novel, acc_tally_one_plus_tool_shared + acc_tally_no_tool)

# %%
overrepd_accs = list(interpro_accessions_in_novel_transcripts(acc_product["domain"], acc_tally_one_plus_tool_novel, only_tools_results, min_freq=10))
# Out:
# InterPro accessions occurring with significantly higher frequency in novel transcripts than in shared transcripts:
# 	IPR019430: 7TM GPCR, serpentine receptor class x (Srx) (14 occurrences, 3 expected)
# 	IPR002486: Nematode cuticle collagen, N-terminal (54 occurrences, 11 expected)
# 	IPR011527: ABC transporter type 1, transmembrane domain (10 occurrences, 2 expected)
# 	IPR003439: ABC transporter-like, ATP-binding domain (14 occurrences, 4 expected)
# 	IPR003599: Immunoglobulin subtype (10 occurrences, 4 expected)
# 	IPR000535: Major sperm protein (MSP) domain (10 occurrences, 4 expected)
# 	IPR003582: ShKT domain (34 occurrences, 13 expected)
# 	IPR017452: GPCR, rhodopsin-like, 7TM (45 occurrences, 18 expected)
# 	IPR007110: Immunoglobulin-like domain (11 occurrences, 5 expected)
# 	IPR014044: CAP domain (35 occurrences, 17 expected)
# 	IPR000742: EGF-like domain (22 occurrences, 11 expected)
# 	IPR001506: Peptidase M12A (17 occurrences, 9 expected)
#
# InterPro accessions that are completely missing from shared transcripts, with high frequency in novel transcripts:

# %%
interpro_accessions_frequently_missed_by_all_tools(flatten_nested_dict(acc_product), acc_tally_no_tool, no_tools_results)
# Out:
# InterPro accessions occurring with significantly higher frequency in transcripts that were missed by all tools, than in transcripts shared by at least 1 tool:
# 	IPR049163: DNA helicase Pif1-like, 2B domain (5 occurrences, 0 expected)
# 	IPR048998: STPR domain (2 occurrences, 0 expected)
# 	IPR036691: Endonuclease/exonuclease/phosphatase superfamily (87 occurrences, 6 expected)
# 	IPR005135: Endonuclease/exonuclease/phosphatase (40 occurrences, 3 expected)
# 	IPR001461: Aspartic peptidase A1 family (26 occurrences, 2 expected)
# 	IPR033121: Peptidase family A1 domain (26 occurrences, 2 expected)
# 	IPR000477: Reverse transcriptase domain (161 occurrences, 15 expected)
# 	IPR010285: DNA helicase Pif1-like (3 occurrences, 0 expected)
# 	IPR043502: DNA/RNA polymerase superfamily (145 occurrences, 15 expected)
# 	IPR018244: Allergen V5/Tpx-1-related, conserved site (29 occurrences, 3 expected)
# 	IPR001969: Aspartic peptidase, active site (37 occurrences, 4 expected)
# 	IPR035940: CAP superfamily (57 occurrences, 7 expected)
# 	IPR043128: Reverse transcriptase/Diguanylate cyclase domain (72 occurrences, 9 expected)
# 	IPR002413: Venom allergen 5-like (28 occurrences, 4 expected)
# 	IPR001995: Peptidase A2A, retrovirus, catalytic (17 occurrences, 3 expected)
# 	IPR021109: Aspartic peptidase domain superfamily (44 occurrences, 8 expected)
# 	IPR036397: Ribonuclease H superfamily (72 occurrences, 13 expected)
# 	IPR048703: Transposable element Tc3 transposase-like, DNA-binding HTH domain (4 occurrences, 1 expected)
# 	IPR001283: Cysteine-rich secretory protein-related (31 occurrences, 6 expected)
# 	IPR040676: Domain of unknown function DUF5641 (14 occurrences, 3 expected)
# 	IPR008737: Peptidase aspartic, putative (15 occurrences, 3 expected)
# 	IPR008042: Retrotransposon, Pao (19 occurrences, 4 expected)
# 	IPR014044: CAP domain (32 occurrences, 6 expected)
# 	IPR041373: Reverse transcriptase, RNase H-like domain (8 occurrences, 2 expected)
# 	IPR035901: GIY-YIG endonuclease superfamily (6 occurrences, 1 expected)
# 	IPR041577: Reverse transcriptase/retrotransposon-derived protein, RNase H-like domain (5 occurrences, 1 expected)
# 	IPR011705: BTB/Kelch-associated (6 occurrences, 1 expected)
# 	IPR005312: Protein of unknown function DUF1759 (20 occurrences, 5 expected)
# 	IPR001888: Transposase, type 1 (7 occurrences, 2 expected)
# 	IPR041588: Integrase zinc-binding domain (18 occurrences, 5 expected)
# 	IPR001584: Integrase, catalytic core (18 occurrences, 5 expected)
# 	IPR027124: SWR1-complex protein 5/Craniofacial development protein 1/2 (6 occurrences, 2 expected)
# 	IPR041426: Mos1 transposase, HTH domain (9 occurrences, 3 expected)
# 	IPR038717: Tc1-like transposase, DDE domain (4 occurrences, 1 expected)
# 	IPR000305: GIY-YIG endonuclease (5 occurrences, 2 expected)
# 	IPR012337: Ribonuclease H-like superfamily (18 occurrences, 7 expected)
# 	IPR001878: Zinc finger, CCHC-type (9 occurrences, 4 expected)
#
# InterPro accessions that are completely missing from transcripts shared by at least 1 tool, but present in transcripts that were missed by all tools:
# 	IPR049511: Polyglycine hydrolase-like, tandem repeat (1 occurrences)
# 	IPR000298: Cytochrome c oxidase subunit III-like (1 occurrences)
# 	IPR013833: Cytochrome c oxidase, subunit III, 4-helical bundle (1 occurrences)
# 	IPR024791: Cytochrome c oxidase subunit III (1 occurrences)
# 	IPR033945: Cytochrome c oxidase subunit III domain (1 occurrences)
# 	IPR035973: Cytochrome c oxidase subunit III-like superfamily (1 occurrences)
# 	IPR000440: NADH:ubiquinone/plastoquinone oxidoreductase, chain 3 (1 occurrences)
# 	IPR038430: NADH:ubiquinone oxidoreductase, subunit 3 superfamily (1 occurrences)
# 	IPR000631: ATP/ADP-dependent (S)-NAD(P)H-hydrate dehydratase (1 occurrences)
# 	IPR018792: Nuclear protein 1-like (1 occurrences)
# 	IPR018615: Large ribosomal subunit protein mL55 (1 occurrences)
# 	IPR044884: Large ribosomal subunit protein mL55 superfamily (1 occurrences)
# 	IPR012621: Mitochondrial import receptor subunit TOM7 (1 occurrences)
# 	IPR021454: Protein of unknown function DUF3105 (1 occurrences)
# 	IPR005341: Mitochondrial import inner membrane translocase subunit Tim16 (1 occurrences)
# 	IPR009787: Protein jagunal (1 occurrences)
# 	IPR019481: Transcription factor TFIIIC, triple barrel domain (1 occurrences)
# 	IPR021859: XRN2-binding (XTBD) domain (1 occurrences)
# 	IPR000077: Large ribosomal subunit protein eL39 (1 occurrences)
# 	IPR023626: Large ribosomal subunit protein eL39 domain superfamily (1 occurrences)
# 	IPR024512: Small subunit of serine palmitoyltransferase-like (1 occurrences)
#
# InterPro accessions occurring as expected in transcripts that were missed by all tools.
# 	IPR007014: FUN14 (1 occurrences, 0 expected)
# 	IPR011041: Soluble quinoprotein glucose/sorbosone dehydrogenase (1 occurrences, 0 expected)
# 	IPR049342: TRAF1-6/MEP1A/B-like, MATH domain (1 occurrences, 0 expected)
# 	IPR025246: Transposase IS30-like HTH domain (1 occurrences, 0 expected)
# 	IPR039808: Cadherin (1 occurrences, 0 expected)
# 	IPR042098: Taurine dioxygenase TauD-like superfamily (1 occurrences, 0 expected)
# 	IPR046427: Legumain prodomain superfamily (1 occurrences, 0 expected)
# 	IPR048501: Legumain, prodomain (1 occurrences, 0 expected)
# 	IPR029056: Ribokinase-like (1 occurrences, 0 expected)
# 	IPR033336: Stabilizer of axonemal microtubules 1/2 (1 occurrences, 0 expected)
# 	IPR019410: Lysine methyltransferase (1 occurrences, 0 expected)
# 	IPR010734: Copine, C-terminal (1 occurrences, 0 expected)
# 	IPR002241: Glycoside hydrolase, family 27 (1 occurrences, 0 expected)
# 	IPR002601: C6 domain (1 occurrences, 0 expected)
# 	IPR001563: Peptidase S10, serine carboxypeptidase (2 occurrences, 0 expected)
# 	IPR018202: Serine carboxypeptidase, serine active site (1 occurrences, 0 expected)
# 	IPR033124: Serine carboxypeptidases, histidine active site (1 occurrences, 0 expected)
# 	IPR001096: Peptidase C13, legumain (1 occurrences, 0 expected)
# 	IPR035127: Uncharacterized strongylid L4 protein (2 occurrences, 0 expected)
# 	IPR047655: Transposase IS630-like (1 occurrences, 0 expected)
# 	IPR003886: NIDO domain (1 occurrences, 0 expected)
# 	IPR002083: MATH/TRAF domain (1 occurrences, 0 expected)
# 	IPR000595: Cyclic nucleotide-binding domain (1 occurrences, 0 expected)
# 	IPR018490: Cyclic nucleotide-binding domain superfamily (1 occurrences, 0 expected)
# 	IPR008974: TRAF-like (1 occurrences, 0 expected)
# 	IPR011043: Galactose oxidase/kelch, beta-propeller (1 occurrences, 0 expected)
# 	IPR020894: Cadherin conserved site (1 occurrences, 0 expected)
# 	IPR042269: Serine carboxypeptidase S28, SKS domain (1 occurrences, 0 expected)
# 	IPR002126: Cadherin-like (1 occurrences, 0 expected)
# 	IPR034164: Pepsin-like domain (2 occurrences, 1 expected)
# 	IPR008758: Peptidase S28 (1 occurrences, 0 expected)
# 	IPR019427: 7TM GPCR, serpentine receptor class w (Srw) (1 occurrences, 0 expected)
# 	IPR001791: Laminin G domain (1 occurrences, 0 expected)
# 	IPR015919: Cadherin-like superfamily (1 occurrences, 0 expected)
# 	IPR018170: Aldo/keto reductase, conserved site (1 occurrences, 0 expected)
# 	IPR006652: Kelch repeat type 1 (3 occurrences, 1 expected)
# 	IPR025898: Tc3 transposase, DNA binding domain (1 occurrences, 1 expected)
# 	IPR006149: EB domain (1 occurrences, 1 expected)
# 	IPR000210: BTB/POZ domain (5 occurrences, 3 expected)
# 	IPR019422: 7TM GPCR, serpentine receptor class h (Srh) (1 occurrences, 1 expected)
# 	IPR020471: Aldo-keto reductase (1 occurrences, 1 expected)
# 	IPR015915: Kelch-type beta propeller (3 occurrences, 2 expected)
# 	IPR036875: Zinc finger, CCHC-type superfamily (5 occurrences, 3 expected)
# 	IPR036465: von Willebrand factor A-like domain superfamily (3 occurrences, 2 expected)
# 	IPR009878: Phlebovirus glycoprotein G2, fusion domain (2 occurrences, 1 expected)
# 	IPR014710: RmlC-like jelly roll fold (1 occurrences, 1 expected)
# 	IPR023210: NADP-dependent oxidoreductase domain (1 occurrences, 1 expected)
# 	IPR036812: NADP-dependent oxidoreductase domain superfamily (1 occurrences, 1 expected)
# 	IPR011333: SKP1/BTB/POZ domain superfamily (5 occurrences, 3 expected)
# 	IPR009057: Homeobox-like domain superfamily (8 occurrences, 5 expected)
# 	IPR012877: Uncharacterised oxidoreductase Dhs-27 (1 occurrences, 1 expected)
# 	IPR000152: EGF-type aspartate/asparagine hydroxylation site (1 occurrences, 1 expected)
# 	IPR008139: Saposin B type domain (1 occurrences, 1 expected)
# 	IPR036869: Chaperone J-domain superfamily (1 occurrences, 1 expected)
# 	IPR001506: Peptidase M12A (4 occurrences, 4 expected)
# 	IPR036388: Winged helix-like DNA-binding domain superfamily (6 occurrences, 6 expected)
# 	IPR019425: 7TM GPCR, serpentine receptor class t (Srt) (1 occurrences, 1 expected)
# 	IPR006150: Cysteine-rich repeat (1 occurrences, 1 expected)
# 	IPR011701: Major facilitator superfamily (2 occurrences, 2 expected)
# 	IPR011001: Saposin-like (1 occurrences, 1 expected)
# 	IPR007110: Immunoglobulin-like domain (2 occurrences, 2 expected)
# 	IPR036259: MFS transporter superfamily (4 occurrences, 4 expected)
# 	IPR036179: Immunoglobulin-like domain superfamily (2 occurrences, 2 expected)
# 	IPR006026: Peptidase, metallopeptidase (3 occurrences, 3 expected)
# 	IPR024079: Metallopeptidase, catalytic domain superfamily (4 occurrences, 5 expected)
# 	IPR001881: EGF-like calcium-binding domain (1 occurrences, 1 expected)
# 	IPR004151: 7TM GPCR, serpentine receptor class e (Sre) (1 occurrences, 1 expected)
# 	IPR002184: 7TM GPCR, serpentine receptor class b (Srb) (1 occurrences, 1 expected)
# 	IPR013785: Aldolase-type TIM barrel (1 occurrences, 1 expected)
# 	IPR029058: Alpha/Beta hydrolase fold (3 occurrences, 4 expected)
# 	IPR001245: Serine-threonine/tyrosine-protein kinase, catalytic domain (2 occurrences, 3 expected)
# 	IPR002035: von Willebrand factor, type A (1 occurrences, 1 expected)
# 	IPR013098: Immunoglobulin I-set (1 occurrences, 1 expected)
# 	IPR020846: Major facilitator superfamily domain (2 occurrences, 3 expected)
# 	IPR020635: Tyrosine-protein kinase, catalytic domain (1 occurrences, 1 expected)
# 	IPR011545: DEAD/DEAH box helicase domain (1 occurrences, 1 expected)
# 	IPR047187: Upf1-like, C-terminal helicase domain (1 occurrences, 2 expected)
# 	IPR003598: Immunoglobulin subtype 2 (1 occurrences, 2 expected)
# 	IPR003599: Immunoglobulin subtype (1 occurrences, 2 expected)
# 	IPR019421: 7TM GPCR, serpentine receptor class d (Srd) (1 occurrences, 2 expected)
# 	IPR041679: DNA2/NAM7 helicase-like, C-terminal (1 occurrences, 2 expected)
# 	IPR013320: Concanavalin A-like lectin/glucanase domain superfamily (1 occurrences, 2 expected)
# 	IPR038479: Transthyretin-like superfamily (1 occurrences, 2 expected)
# 	IPR001534: Transthyretin-like (1 occurrences, 2 expected)
# 	IPR035126: Secreted clade V protein (1 occurrences, 2 expected)
# 	IPR001650: Helicase, C-terminal (1 occurrences, 2 expected)
# 	IPR014001: Helicase superfamily 1/2, ATP-binding domain (1 occurrences, 2 expected)
# 	IPR000859: CUB domain (1 occurrences, 2 expected)
# 	IPR019424: Serpentine type 7TM GPCR chemoreceptor Srsx (1 occurrences, 2 expected)
# 	IPR035914: Spermadhesin, CUB domain superfamily (1 occurrences, 3 expected)
# 	IPR013783: Immunoglobulin-like fold (2 occurrences, 5 expected)
# 	IPR016187: C-type lectin fold (1 occurrences, 3 expected)
# 	IPR029063: S-adenosyl-L-methionine-dependent methyltransferase superfamily (1 occurrences, 3 expected)
# 	IPR036236: Zinc finger C2H2 superfamily (1 occurrences, 3 expected)
# 	IPR000742: EGF-like domain (1 occurrences, 5 expected)
# 	IPR013087: Zinc finger C2H2-type (1 occurrences, 5 expected)
# 	IPR008160: Collagen triple helix repeat (1 occurrences, 5 expected)

# %% [markdown]
# Find accessions that are significantly commonly missed by each tool.

# %%
interpro_accessions_frequently_missed_by_each_tool(
    flatten_nested_dict(acc_product),
    {
        "BRAKER3": braker3_missed_results,
        "Helixer": helixer_missed_results,
        "Anno": anno_missed_results
    },
    {
        "BRAKER3": acc_tally_missed_braker3,
        "Helixer": acc_tally_missed_helixer,
        "Anno": acc_tally_missed_anno
    }
)
# Out:
# IPR001969: Aspartic peptidase, active site
# 9.04 times more likely than with BRAKER3 (117 occurrences, 13 expected)
# 5.21 times more likely than with Helixer (49 occurrences, 9 expected)
# 7.36 times more likely than with Anno (73 occurrences, 10 expected)
# ~~~~~~~~~~
# IPR041373: Reverse transcriptase, RNase H-like domain
# 23.29 times more likely than with BRAKER3 (56 occurrences, 2 expected)
# 5.13 times more likely than with Helixer (18 occurrences, 4 expected)
# 9.76 times more likely than with Anno (32 occurrences, 3 expected)
# ~~~~~~~~~~
# IPR001584: Integrase, catalytic core
# 25.94 times more likely than with BRAKER3 (164 occurrences, 6 expected)
# 3.76 times more likely than with Helixer (41 occurrences, 11 expected)
# 7.63 times more likely than with Anno (79 occurrences, 10 expected)
# ~~~~~~~~~~
# IPR041426: Mos1 transposase, HTH domain
# 5.55 times more likely than with BRAKER3 (49 occurrences, 9 expected)
# 2.81 times more likely than with Helixer (16 occurrences, 6 expected)
# 2.45 times more likely than with Anno (17 occurrences, 7 expected)
# ~~~~~~~~~~
# IPR041679: DNA2/NAM7 helicase-like, C-terminal
# 9.71 times more likely than with BRAKER3 (39 occurrences, 4 expected)
# 2.5 times more likely than with Helixer (9 occurrences, 4 expected)
# 3.21 times more likely than with Anno (14 occurrences, 4 expected)
# ~~~~~~~~~~
# IPR040676: Domain of unknown function DUF5641
# 20.76 times more likely than with BRAKER3 (87 occurrences, 4 expected)
# 3.6 times more likely than with Helixer (22 occurrences, 6 expected)
# 10.34 times more likely than with Anno (52 occurrences, 5 expected)
# ~~~~~~~~~~
# IPR041588: Integrase zinc-binding domain
# 24.78 times more likely than with BRAKER3 (152 occurrences, 6 expected)
# 3.31 times more likely than with Helixer (35 occurrences, 11 expected)
# 8.39 times more likely than with Anno (78 occurrences, 9 expected)
# ~~~~~~~~~~
# IPR021109: Aspartic peptidase domain superfamily
# 11.29 times more likely than with BRAKER3 (213 occurrences, 19 expected)
# 3.75 times more likely than with Helixer (64 occurrences, 17 expected)
# 8.11 times more likely than with Anno (130 occurrences, 16 expected)
# ~~~~~~~~~~
# IPR036691: Endonuclease/exonuclease/phosphatase superfamily
# 4.32 times more likely than with BRAKER3 (135 occurrences, 31 expected)
# 15.7 times more likely than with Helixer (151 occurrences, 10 expected)
# 8.9 times more likely than with Anno (128 occurrences, 14 expected)
# ~~~~~~~~~~
# IPR009878: Phlebovirus glycoprotein G2, fusion domain
# 5.19 times more likely than with BRAKER3 (23 occurrences, 4 expected)
# 5.6 times more likely than with Helixer (13 occurrences, 2 expected)
# 8.22 times more likely than with Anno (19 occurrences, 2 expected)
# ~~~~~~~~~~
# IPR036397: Ribonuclease H superfamily
# 16.96 times more likely than with BRAKER3 (403 occurrences, 24 expected)
# 5.08 times more likely than with Helixer (137 occurrences, 27 expected)
# 5.07 times more likely than with Anno (161 occurrences, 32 expected)
# ~~~~~~~~~~
# IPR014044: CAP domain
# 6.17 times more likely than with BRAKER3 (130 occurrences, 21 expected)
# 3.19 times more likely than with Helixer (43 occurrences, 13 expected)
# 3.52 times more likely than with Anno (56 occurrences, 16 expected)
# ~~~~~~~~~~
# IPR012337: Ribonuclease H-like superfamily
# 12.18 times more likely than with BRAKER3 (178 occurrences, 15 expected)
# 2.93 times more likely than with Helixer (43 occurrences, 15 expected)
# 5.43 times more likely than with Anno (82 occurrences, 15 expected)
# ~~~~~~~~~~
# IPR008737: Peptidase aspartic, putative
# 22.45 times more likely than with BRAKER3 (94 occurrences, 4 expected)
# 4.08 times more likely than with Helixer (26 occurrences, 6 expected)
# 9.88 times more likely than with Anno (54 occurrences, 5 expected)
# ~~~~~~~~~~
# IPR027124: SWR1-complex protein 5/Craniofacial development protein 1/2
# 3.69 times more likely than with BRAKER3 (26 occurrences, 7 expected)
# 22.71 times more likely than with Helixer (38 occurrences, 2 expected)
# 8.45 times more likely than with Anno (27 occurrences, 3 expected)
# ~~~~~~~~~~
# IPR001461: Aspartic peptidase A1 family
# 3.58 times more likely than with BRAKER3 (41 occurrences, 11 expected)
# 6.93 times more likely than with Helixer (32 occurrences, 5 expected)
# 6.09 times more likely than with Anno (34 occurrences, 6 expected)
# ~~~~~~~~~~
# IPR018244: Allergen V5/Tpx-1-related, conserved site
# 13.37 times more likely than with BRAKER3 (96 occurrences, 7 expected)
# 4.86 times more likely than with Helixer (33 occurrences, 7 expected)
# 6.68 times more likely than with Anno (49 occurrences, 7 expected)
# ~~~~~~~~~~
# IPR036875: Zinc finger, CCHC-type superfamily
# 13.04 times more likely than with BRAKER3 (73 occurrences, 6 expected)
# 2.07 times more likely than with Helixer (13 occurrences, 6 expected)
# 7.17 times more likely than with Anno (40 occurrences, 6 expected)
# ~~~~~~~~~~
# IPR001283: Cysteine-rich secretory protein-related
# 6.47 times more likely than with BRAKER3 (121 occurrences, 19 expected)
# 3.49 times more likely than with Helixer (42 occurrences, 12 expected)
# 3.61 times more likely than with Anno (52 occurrences, 14 expected)
# ~~~~~~~~~~
# IPR043128: Reverse transcriptase/Diguanylate cyclase domain
# 8.74 times more likely than with BRAKER3 (260 occurrences, 30 expected)
# 5.98 times more likely than with Helixer (120 occurrences, 20 expected)
# 6.58 times more likely than with Anno (150 occurrences, 23 expected)
# ~~~~~~~~~~
# IPR001888: Transposase, type 1
# 5.8 times more likely than with BRAKER3 (35 occurrences, 6 expected)
# 4.18 times more likely than with Helixer (15 occurrences, 4 expected)
# 3.52 times more likely than with Anno (16 occurrences, 5 expected)
# ~~~~~~~~~~
# IPR043502: DNA/RNA polymerase superfamily
# 8.69 times more likely than with BRAKER3 (444 occurrences, 51 expected)
# 6.61 times more likely than with Helixer (218 occurrences, 33 expected)
# 6.5 times more likely than with Anno (253 occurrences, 39 expected)
# ~~~~~~~~~~
# IPR005312: Protein of unknown function DUF1759
# 29.41 times more likely than with BRAKER3 (157 occurrences, 5 expected)
# 4.48 times more likely than with Helixer (45 occurrences, 10 expected)
# 8.19 times more likely than with Anno (79 occurrences, 10 expected)
# ~~~~~~~~~~
# IPR001878: Zinc finger, CCHC-type
# 14.48 times more likely than with BRAKER3 (101 occurrences, 7 expected)
# 2.41 times more likely than with Helixer (20 occurrences, 8 expected)
# 5.9 times more likely than with Anno (48 occurrences, 8 expected)
# ~~~~~~~~~~
# IPR035940: CAP superfamily
# 6.45 times more likely than with BRAKER3 (161 occurrences, 25 expected)
# 4.79 times more likely than with Helixer (72 occurrences, 15 expected)
# 5.0 times more likely than with Anno (86 occurrences, 17 expected)
# ~~~~~~~~~~
# IPR002413: Venom allergen 5-like
# 8.3 times more likely than with BRAKER3 (96 occurrences, 12 expected)
# 4.2 times more likely than with Helixer (35 occurrences, 8 expected)
# 4.38 times more likely than with Anno (43 occurrences, 10 expected)
# ~~~~~~~~~~
# IPR001995: Peptidase A2A, retrovirus, catalytic
# 23.57 times more likely than with BRAKER3 (94 occurrences, 4 expected)
# 3.03 times more likely than with Helixer (20 occurrences, 7 expected)
# 9.39 times more likely than with Anno (53 occurrences, 6 expected)
# ~~~~~~~~~~
# IPR033121: Peptidase family A1 domain
# 3.52 times more likely than with BRAKER3 (41 occurrences, 12 expected)
# 6.83 times more likely than with Helixer (32 occurrences, 5 expected)
# 5.9 times more likely than with Anno (34 occurrences, 6 expected)
# ~~~~~~~~~~
# IPR008042: Retrotransposon, Pao
# 22.3 times more likely than with BRAKER3 (124 occurrences, 6 expected)
# 5.74 times more likely than with Helixer (44 occurrences, 8 expected)
# 7.61 times more likely than with Anno (61 occurrences, 8 expected)
# ~~~~~~~~~~
# IPR000477: Reverse transcriptase domain
# 7.73 times more likely than with BRAKER3 (441 occurrences, 57 expected)
# 7.5 times more likely than with Helixer (245 occurrences, 33 expected)
# 6.71 times more likely than with Anno (268 occurrences, 40 expected)
# ~~~~~~~~~~
# IPR049163: DNA helicase Pif1-like, 2B domain
# 7.94 times more likely than with BRAKER3 (8 occurrences, 1 expected)
# 8.87 times more likely than with Helixer (5 occurrences, 1 expected)
# 6.23 times more likely than with Anno (5 occurrences, 1 expected)
# ~~~~~~~~~~
# IPR005135: Endonuclease/exonuclease/phosphatase
# 3.68 times more likely than with BRAKER3 (59 occurrences, 16 expected)
# 9.11 times more likely than with Helixer (55 occurrences, 6 expected)
# 7.56 times more likely than with Anno (56 occurrences, 7 expected)
# ~~~~~~~~~~

# %%
import re
MIN_WORD_LEN = 5
tools_missed_results = {
    "BRAKER3": braker3_missed_results,
    "Helixer": helixer_missed_results,
    "Anno": anno_missed_results
}
tools_novel_results = {
    "BRAKER3": braker3_novel_results,
    "Helixer": helixer_novel_results,
    "Anno": anno_novel_results
}
acc_tally_missed_tools = {
    "BRAKER3": acc_tally_missed_braker3,
    "Helixer": acc_tally_missed_helixer,
    "Anno": acc_tally_missed_anno
}
acc_tally_novel_tools = {
    "BRAKER3": acc_tally_novel_braker3,
    "Helixer": acc_tally_novel_helixer,
    "Anno": acc_tally_novel_anno
}
seen_words = set()
all_words = set()
for acc in set.intersection(*[set(results["more_frequent"].keys()) for results in tools_missed_results.values()]):
    prod = flatten_nested_dict(acc_product)[acc]
    words = [w for w in re.split(r'\W', prod.lower()) if w and len(w) >= MIN_WORD_LEN]
    all_words.update(words)
    # Check if words occur more frequently in novel-only accessions
    for novel_acc in set.intersection(*[set(results["more_frequent"].keys()) for results in tools_novel_results.values()]):
        novel_prod = flatten_nested_dict(acc_product)[novel_acc]
        for w in words:
            if w in novel_prod.lower():
                print(f"{w} appears in {novel_acc}: {novel_prod}")
                seen_words.add(w)
# Out:
# domain appears in IPR003582: ShKT domain
# domain appears in IPR003582: ShKT domain
# terminal appears in IPR002486: Nematode cuticle collagen, N-terminal
# domain appears in IPR003582: ShKT domain
# domain appears in IPR003582: ShKT domain
# domain appears in IPR003582: ShKT domain
# domain appears in IPR003582: ShKT domain
# domain appears in IPR003582: ShKT domain
# domain appears in IPR003582: ShKT domain
# domain appears in IPR003582: ShKT domain
# domain appears in IPR003582: ShKT domain
# domain appears in IPR003582: ShKT domain

# %%
from reannotation.pipelines import count_prod_word_occurrence_for_signif_accs
count_prod_word_occurrence_for_signif_accs(
    acc_tally_no_tool,
    acc_tally_no_tool + acc_tally_one_plus_tool_shared + acc_tally_one_plus_tool_novel,
    flatten_nested_dict(acc_product)
)
# Out:
# [('superfamily', 218291), ('domain', 194630), ('reverse', 154764), ('transcriptase', 154764), ('dna', 108305), ('rna', 106720), ('polymerase', 106720), ('h', 44458), ('ribonuclease', 43650), ('endonuclease', 33908), ('exonuclease', 33264), ('phosphatase', 33264), ('peptidase', 31386), ('', 30629), ('diguanylate', 30168), ('cyclase', 30168), ('cap', 26998), ('aspartic', 25652), ('like', 15825), ('protein', 14191), ('related', 11585), ('site', 11210), ('allergen', 8768), ('cysteine', 7447), ('rich', 7447), ('secretory', 7409), ('active', 6972), ('integrase', 6930), ('catalytic', 6519), ('zinc', 5486), ('hydrolase', 5450), ('of', 5449), ('unknown', 5441), ('function', 5441), ('family', 5363), ('a1', 5356), ('1', 5301), ('p', 5017), ('loop', 5016), ('containing', 5016), ('nucleoside', 5016), ('triphosphate', 5016), ('5', 4988), ('binding', 4985), ('venom', 4592), ('conserved', 4207), ('v5', 4176), ('tpx', 4176), ('duf1759', 3900), ('core', 3564), ('type', 3181), ('retrotransposon', 3161), ('pao', 2926), ('finger', 2120), ('a2a', 2023), ('retrovirus', 2023), ('cchc', 1812), ('putative', 1770), ('kinase', 1738), ('transposase', 1713), ('homeobox', 1616), ('duf5641', 1540), ('helix', 1527), ('btb', 1442), ('winged', 1338), ('poz', 1100), ('metallopeptidase', 1070), ('hth', 1029), ('fold', 948), ('mos1', 909), ('immunoglobulin', 876), ('rnase', 787), ('kelch', 709), ('giy', 644), ('yig', 644), ('mfs', 640), ('transporter', 640), ('beta', 625), ('skp1', 605), ('m12a', 548), ('2', 536), ('helicase', 440), ('alpha', 426), ('terminal', 403), ('swr1', 396), ('complex', 396), ('craniofacial', 396), ('development', 396), ('repeat', 396), ('collagen', 387), ('major', 346), ('facilitator', 346), ('associated', 342), ('c', 316), ('7tm', 312), ('gpcr', 312), ('serpentine', 312), ('a', 308), ('c2h2', 308), ('serine', 261), ('egf', 242), ('tyrosine', 240), ('factor', 238), ('von', 237), ('willebrand', 237), ('derived', 235), ('receptor', 225), ('class', 224), ('propeller', 199), ('nematode', 198), ('cuticle', 198), ('n', 198), ('threonine', 190), ('triple', 190), ('tc1', 180), ('dde', 180), ('lectin', 177), ('cub', 177), ('dependent', 162), ('transthyretin', 145), ('tc3', 135), ('methyltransferase', 120), ('transposable', 116), ('element', 116), ('s', 114), ('subtype', 114), ('adenosyl', 113), ('l', 113), ('methionine', 113), ('pif1', 112), ('spermadhesin', 95), ('phlebovirus', 92), ('glycoprotein', 92), ('g2', 92), ('fusion', 92), ('chemoreceptor', 88), ('srsx', 88), ('oxidoreductase', 78), ('atp', 78), ('b', 78), ('secreted', 76), ('clade', 76), ('v', 76), ('saposin', 72), ('concanavalin', 71), ('glucanase', 71), ('2b', 70), ('dna2', 66), ('nam7', 66), ('d', 62), ('srd', 62), ('pepsin', 60), ('upf1', 55), ('carboxypeptidase', 54), ('dead', 53), ('deah', 53), ('box', 53), ('cadherin', 49), ('nadp', 48), ('i', 48), ('set', 48), ('barrel', 47), ('aldolase', 46), ('tim', 46), ('calcium', 44), ('e', 44), ('sre', 44), ('srb', 44), ('aldo', 38), ('keto', 38), ('reductase', 38), ('t', 38), ('srt', 38), ('27', 35), ('uncharacterized', 34), ('strongylid', 34), ('l4', 34), ('chaperone', 34), ('j', 34), ('s10', 32), ('aspartate', 31), ('asparagine', 31), ('hydroxylation', 31), ('s28', 29), ('uncharacterised', 28), ('dhs', 28), ('cyclic', 24), ('nucleotide', 24), ('rmlc', 24), ('jelly', 24), ('roll', 24), ('traf', 23), ('srh', 20), ('eb', 19), ('oxidase', 18), ('legumain', 18), ('laminin', 17), ('g', 17), ('w', 16), ('srw', 16), ('sks', 14), ('subunit', 13), ('galactose', 13), ('math', 13), ('stpr', 12), ('prodomain', 10), ('is630', 9), ('nido', 9), ('carboxypeptidases', 8), ('histidine', 8), ('c13', 8), ('stabilizer', 7), ('axonemal', 7), ('microtubules', 7), ('lysine', 7), ('copine', 7), ('glycoside', 7), ('c6', 7), ('ribokinase', 6), ('cytochrome', 5), ('iii', 5), ('taurine', 5), ('dioxygenase', 5), ('taud', 5), ('large', 4), ('ribosomal', 4), ('is30', 4), ('nadh', 2), ('ubiquinone', 2), ('3', 2), ('ml55', 2), ('fun14', 2), ('mitochondrial', 2), ('import' ...

# %%
all_words.difference(seen_words)
# Out:
# {'active',
#  'allergen',
#  'aspartic',
#  'binding',
#  'catalytic',
#  'complex',
#  'conserved',
#  'craniofacial',
#  'cyclase',
#  'cysteine',
#  'development',
#  'diguanylate',
#  'duf1759',
#  'duf5641',
#  'endonuclease',
#  'exonuclease',
#  'family',
#  'finger',
#  'function',
#  'fusion',
#  'glycoprotein',
#  'helicase',
#  'integrase',
#  'peptidase',
#  'phlebovirus',
#  'phosphatase',
#  'polymerase',
#  'protein',
#  'putative',
#  'related',
#  'retrotransposon',
#  'retrovirus',
#  'reverse',
#  'ribonuclease',
#  'rnase',
#  'secretory',
#  'superfamily',
#  'transcriptase',
#  'transposase',
#  'unknown',
#  'venom'}

# %%
word = "aspartic"

def frequency_of_word(word, tool_tally, acc_product):
    for tool, acc_tally in tool_tally.items():
        for acc, freq in Counter(acc_tally).items():
            try:
                prod = acc_product[acc]
            except Exception as e:
                print(e)
            if word in prod.lower():
                print(f"{tool}: word '{word}' occurs in {acc} with frequency {freq}")
    

def find_word_in_accessions(word, acc_product):
    for acc, prod in acc_product.items():
        if word in prod.lower():
            print(f"{acc}: {prod}")

            
find_word_in_accessions(word, flatten_nested_dict(acc_product))
print("MISSED")
frequency_of_word(word, acc_tally_missed_tools, flatten_nested_dict(acc_product))
print("NOVEL")
frequency_of_word(word, acc_tally_novel_tools, flatten_nested_dict(acc_product))
# Out:
# IPR001969: Aspartic peptidase, active site
# IPR033112: Phospholipase A2, aspartic acid active site
# IPR008737: Peptidase aspartic, putative
# IPR012848: Aspartic peptidase, N-terminal
# IPR019103: Aspartic peptidase, DDI1-type
# IPR001461: Aspartic peptidase A1 family
# IPR021109: Aspartic peptidase domain superfamily
# MISSED
# BRAKER3: word 'aspartic' occurs in IPR001461 with frequency 41
# BRAKER3: word 'aspartic' occurs in IPR001969 with frequency 117
# BRAKER3: word 'aspartic' occurs in IPR021109 with frequency 213
# BRAKER3: word 'aspartic' occurs in IPR008737 with frequency 94
# Helixer: word 'aspartic' occurs in IPR001969 with frequency 49
# Helixer: word 'aspartic' occurs in IPR021109 with frequency 64
# Helixer: word 'aspartic' occurs in IPR008737 with frequency 26
# Helixer: word 'aspartic' occurs in IPR001461 with frequency 32
# 'IPR039037'
# Anno: word 'aspartic' occurs in IPR001461 with frequency 34
# Anno: word 'aspartic' occurs in IPR001969 with frequency 73
# Anno: word 'aspartic' occurs in IPR021109 with frequency 130
# 'IPR026515'
# Anno: word 'aspartic' occurs in IPR008737 with frequency 54
# NOVEL
# 'IPR050632'
# BRAKER3: word 'aspartic' occurs in IPR021109 with frequency 3
# BRAKER3: word 'aspartic' occurs in IPR001461 with frequency 2
# 'IPR050632'
# Helixer: word 'aspartic' occurs in IPR021109 with frequency 4
# Helixer: word 'aspartic' occurs in IPR008737 with frequency 2
# Helixer: word 'aspartic' occurs in IPR001969 with frequency 2
# Helixer: word 'aspartic' occurs in IPR001461 with frequency 2
# 'IPR042978'
# 'IPR050632'
# Anno: word 'aspartic' occurs in IPR021109 with frequency 9
# Anno: word 'aspartic' occurs in IPR001969 with frequency 4
# Anno: word 'aspartic' occurs in IPR008737 with frequency 1
# Anno: word 'aspartic' occurs in IPR001461 with frequency 1
# 'IPR050702'

# %%
for ap_acc in ASPARTIC_PEPTIDASE_SUPERFAMILY + ["IPR001969", "IPR008737"]:
    if ap_acc in flatten_nested_dict(acc_product):
        print(f"{ap_acc}: {flatten_nested_dict(acc_product)[ap_acc]}")
    for tool, results in tools_missed_results.items():
        for cat, accs in results.items():
            for acc in accs:
                if acc == ap_acc:
                    print(f"\t{tool} missed - {cat}")
    for tool, results in tools_novel_results.items():
        for cat, accs in results.items():
            for acc in accs:
                if acc == ap_acc:
                    print(f"\t{tool} novel - {cat}")
# Out:
# IPR021109: Aspartic peptidase domain superfamily
# 	BRAKER3 missed - more_frequent
# 	Helixer missed - more_frequent
# 	Anno missed - more_frequent
# 	BRAKER3 novel - as_expected
# 	Helixer novel - as_expected
# 	Anno novel - as_expected
# IPR001995: Peptidase A2A, retrovirus, catalytic
# 	BRAKER3 missed - more_frequent
# 	Helixer missed - more_frequent
# 	Anno missed - more_frequent
# 	Anno novel - as_expected
# IPR012848: Aspartic peptidase, N-terminal
# IPR018061: Retropepsins
# 	BRAKER3 missed - not_occurring
# IPR019103: Aspartic peptidase, DDI1-type
# IPR033121: Peptidase family A1 domain
# 	BRAKER3 missed - more_frequent
# 	Helixer missed - more_frequent
# 	Anno missed - more_frequent
# 	BRAKER3 novel - as_expected
# 	Helixer novel - as_expected
# 	Anno novel - as_expected
# IPR034164: Pepsin-like domain
# 	BRAKER3 missed - as_expected
# 	Helixer missed - as_expected
# 	Anno missed - as_expected
# 	BRAKER3 novel - as_expected
# IPR001461: Aspartic peptidase A1 family
# 	BRAKER3 missed - more_frequent
# 	Helixer missed - more_frequent
# 	Anno missed - more_frequent
# 	BRAKER3 novel - as_expected
# 	Helixer novel - as_expected
# 	Anno novel - as_expected
# IPR001969: Aspartic peptidase, active site
# 	BRAKER3 missed - more_frequent
# 	Helixer missed - more_frequent
# 	Anno missed - more_frequent
# 	Helixer novel - as_expected
# 	Anno novel - as_expected
# IPR008737: Peptidase aspartic, putative
# 	BRAKER3 missed - more_frequent
# 	Helixer missed - more_frequent
# 	Anno missed - more_frequent
# 	Helixer novel - as_expected
# 	Anno novel - as_expected

# %%
from reannotation.utils import extract_accessions_from_transcript
from collections import defaultdict

all_cds_counts = []
ap_cds_counts = []
all_prot_lens = []
ap_prot_lens = []
transcript_count = 0
for t in wbps_species.db.all_features(featuretype="mRNA"):
    cds_exons = list(wbps_species.db.children(t, featuretype="CDS"))
    prot_len = wbps_species.get_amino_acid_count(cds_exons)
    all_cds_counts.append(len(cds_exons))
    all_prot_lens.append(prot_len)
    transcript_has_ap_acc = False
    for acc, prod in extract_accessions_from_transcript(t):
        if acc in ASPARTIC_PEPTIDASE_SUPERFAMILY:
            ap_cds_counts.append(len(cds_exons))
            ap_prot_lens.append(prot_len)
            transcript_has_ap_acc = True
    if transcript_has_ap_acc:
        transcript_count += 1

# %%
print(statistics.median(all_cds_counts))
print(statistics.median(ap_cds_counts))
print(statistics.mean(all_prot_lens))
print(statistics.mean(ap_prot_lens))

transcript_count
# Out:
# 7.0
# 4.0
# 407.471904315197
# 731.6088957055215
# 321

# %% [markdown]
# # Novel orthologues

# %%
print("Novel transcripts (% of total predicted by tool)")

shared_braker_genes = len(og_df[~og_df[wbps_col].isna() & ~og_df[braker_col].isna()][braker_col].str.split(",").explode().unique())
novel_braker_orths = len(og_df[og_df[wbps_col].isna() & ~og_df[braker_col].isna()][braker_col].str.split(",").explode().unique())
novel_braker_ungs = len(no_og_df[no_og_df[wbps_col].isna() & ~no_og_df[braker_col].isna()][braker_col].str.split(",").explode().unique())
assert shared_braker_genes + novel_braker_orths + novel_braker_ungs == len(braker_species.all_transcript_ids)
print(f"BRAKER3: {novel_braker_orths + novel_braker_ungs} ({round(100*(novel_braker_orths + novel_braker_ungs)/len(braker_species.all_transcript_ids), 2)}%)")


shared_helixer_genes = len(og_df[~og_df[wbps_col].isna() & ~og_df[helixer_col].isna()][helixer_col].str.split(",").explode().unique())
novel_helixer_orths = len(og_df[og_df[wbps_col].isna() & ~og_df[helixer_col].isna()][helixer_col].str.split(",").explode().unique())
novel_helixer_ungs = len(no_og_df[no_og_df[wbps_col].isna() & ~no_og_df[helixer_col].isna()][helixer_col].str.split(",").explode().unique())
assert shared_helixer_genes + novel_helixer_orths + novel_helixer_ungs == len(helixer_species.all_transcript_ids)
print(f"Helixer: {novel_helixer_orths + novel_helixer_ungs} ({round(100*(novel_helixer_orths + novel_helixer_ungs)/len(helixer_species.all_transcript_ids), 2)}%)")

shared_anno_genes = len(og_df[~og_df[wbps_col].isna() & ~og_df[anno_col].isna()][anno_col].str.split(",").explode().unique())
novel_anno_orths = len(og_df[og_df[wbps_col].isna() & ~og_df[anno_col].isna()][anno_col].str.split(",").explode().unique())
novel_anno_ungs = len(no_og_df[no_og_df[wbps_col].isna() & ~no_og_df[anno_col].isna()][anno_col].str.split(",").explode().unique())
assert shared_anno_genes + novel_anno_orths + novel_anno_ungs == len(anno_species.all_transcript_ids)
print(f"Anno: {novel_anno_orths + novel_anno_ungs} ({round(100*(novel_anno_orths + novel_anno_ungs)/len(anno_species.all_transcript_ids), 2)}%)")
# Out:
# Novel transcripts (% of total predicted by tool)
# BRAKER3: 1458 (10.07%)
# Helixer: 3565 (18.61%)
# Anno: 4917 (23.48%)

# %%
## Run once to populate
# novel_orthologue_pipeline(no_og_df, wbps_col, anno_col, species_list, out_dir="data/novel_orthologue_sequences/hcon/anno/unassigned_genes/")
# novel_orthologue_pipeline(no_og_df, wbps_col, braker_col, species_list, out_dir="data/novel_orthologue_sequences/hcon/braker3/unassigned_genes/")
# novel_orthologue_pipeline(no_og_df, wbps_col, helixer_col, species_list, out_dir="data/novel_orthologue_sequences/hcon/helixer/unassigned_genes/")

# %%
## Run once to populate
# novel_orthologue_pipeline(og_df, wbps_col, anno_col, species_list, out_dir="data/novel_orthologue_sequences/hcon/anno/")
# novel_orthologue_pipeline(og_df, wbps_col, braker_col, species_list, out_dir="data/novel_orthologue_sequences/hcon/braker3/")
# novel_orthologue_pipeline(og_df, wbps_col, helixer_col, species_list, out_dir="data/novel_orthologue_sequences/hcon/helixer/")
anno_esm_means = extract_esm_means("data/from_MARS/Hcon_esm_pLDDTs_anno.txt").values()
braker3_esm_means = extract_esm_means("data/from_MARS/Hcon_esm_pLDDTs_braker3.txt").values()
helixer_esm_means = extract_esm_means("data/from_MARS/Hcon_esm_pLDDTs_helixer.txt").values()

print(statistics.mean(map(float, anno_esm_means)))
print(statistics.mean(map(float, braker3_esm_means)))
print(statistics.mean(map(float, helixer_esm_means)))

# %%
import pandas as pd
cols = (
    "fn",
    "mean",
    "median",
    "stdev",
    "var",
    "max",
    "min",
    "perc_confident"
)
df = pd.read_csv("data/from_MARS/pLDDT_hcon.csv", names=cols)
print(f"Mean of means: {df['mean'].mean()}")
print(f"% that are \"Confident\": {100*df[df['mean'] >= 70].shape[0]/df.shape[0]}")

# %%
df_anno = pd.read_csv("data/from_MARS/pLDDT_hcon_anno.csv", names=cols)
df_braker3 = pd.read_csv("data/from_MARS/pLDDT_hcon_braker3.csv", names=cols)
df_helixer = pd.read_csv("data/from_MARS/pLDDT_hcon_helixer.csv", names=cols)

# %%
print(f"Mean of WBPS % that are \"Confident\" residues: {df['perc_confident'].mean()}")
print(f"Mean of BRAKER3 % that are \"Confident\" residues: {df_braker3['perc_confident'].mean()}")
print(f"Mean of Anno % that are \"Confident\" residues: {df_anno['perc_confident'].mean()}")
print(f"Mean of Helixer % that are \"Confident\" residues: {df_helixer['perc_confident'].mean()}")
